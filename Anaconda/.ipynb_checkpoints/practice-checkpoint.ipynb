# %%
class FizzBuzz:
    
    def run(self):
        for x in range(100):
            if x%3 == 0 and x%5 == 0:
                print(f"{x} fizzbuzz")
            elif x%5 == 0:
                print(f"{x} fizz")
            elif x%3 == 0:
                print(f"{x} buzz")
            else:
                print(x)
                
run = FizzBuzz()
run.run()
# Out:
# 0 fizzbuzz
# 1
# 2
# 3 buzz
# 4
# 5 fizz
# 6 buzz
# 7
# 8
# 9 buzz
# 10 fizz
# 11
# 12 buzz
# 13
# 14
# 15 fizzbuzz
# 16
# 17
# 18 buzz
# 19
# 20 fizz
# 21 buzz
# 22
# 23
# 24 buzz
# 25 fizz
# 26
# 27 buzz
# 28
# 29
# 30 fizzbuzz
# 31
# 32
# 33 buzz
# 34
# 35 fizz
# 36 buzz
# 37
# 38
# 39 buzz
# 40 fizz
# 41
# 42 buzz
# 43
# 44
# 45 fizzbuzz
# 46
# 47
# 48 buzz
# 49
# 50 fizz
# 51 buzz
# 52
# 53
# 54 buzz
# 55 fizz
# 56
# 57 buzz
# 58
# 59
# 60 fizzbuzz
# 61
# 62
# 63 buzz
# 64
# 65 fizz
# 66 buzz
# 67
# 68
# 69 buzz
# 70 fizz
# 71
# 72 buzz
# 73
# 74
# 75 fizzbuzz
# 76
# 77
# 78 buzz
# 79
# 80 fizz
# 81 buzz
# 82
# 83
# 84 buzz
# 85 fizz
# 86
# 87 buzz
# 88
# 89
# 90 fizzbuzz
# 91
# 92
# 93 buzz
# 94
# 95 fizz
# 96 buzz
# 97
# 98
# 99 buzz

# %%
letter = []
def func(x):
    return letter[x]
# Out:
#   File "<ipython-input-1-bd543282666a>", line 1
#     letter =
#              ^
# SyntaxError: invalid syntax
